# %% [markdown]
# # Matplotlib #

# %%
import matplotlib.pyplot as plt 
import numpy as np
import pandas as pd

# %% [markdown]
# ### 1.) Basic Graph ###

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

# Step 1 - Resize your graph
plt.figure(figsize=(8, 5), dpi=100)  # figsize indicates the width and height of the graph

# Step 2 - Keyword argument notation 
plt.plot(x, y, 'b^--', label='2x')  # Line 1 Create a plot with blue triangle-up markers and dashed line, labeled '2x'

#Step 3 - For line 2

x2=np.arange(0,4.5,0.5) #select which points to be plotted 

plt.plot(x2[:6], x2[:6]**2, 'r', label='X^2')   # Plot part of the graph as line

plt.plot(x2[5:], x2[5:]**2, 'r--') # Plot remainder of graph as a dot

# Step 4 Add a title 

plt.title('Our First Graph!', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})

# Step 5 - Add X and Y Labels:

plt.xlabel('X axis')
plt.ylabel('Y axis')

#Step 6 - Add a Legend 

plt.legend()

# Step 7 - Show graph 

plt.show()
# Out:
# findfont: Font family 'Comic Sans MS' not found.
# findfont: Font family 'Comic Sans MS' not found.
# findfont: Font family 'Comic Sans MS' not found.
# findfont: Font family 'Comic Sans MS' not found.
# findfont: Font family 'Comic Sans MS' not found.
