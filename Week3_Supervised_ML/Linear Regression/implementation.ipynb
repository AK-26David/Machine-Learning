# %% [markdown]
# # Linear Regression Implementation using sklearn #

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
from sklearn import linear_model
import math

# %%
d = pd.read_csv("homeprices.csv")
print(df)
# Out:
#     area
# 0   1000
# 1   1500
# 2   2300
# 3   3540
# 4   4120
# 5   4560
# 6   5490
# 7   3460
# 8   4750
# 9   2300
# 10  9000
# 11  8600
# 12  7100

# %%
# %matplotlib inline 
plt.xlabel('area(sqr ft)')
plt.ylabel('price ($)')
plt.scatter(d.area, d.price, color='red')

# %%
reg = linear_model.LinearRegression()
reg.fit(d[['area']], d.price)
# Out:
# LinearRegression()

# %%
new_area = np.array([3300]).reshape(-1, 1) # x value,,Reshapping it into a 2d array #
predicted_price = reg.predict(new_area)
print(predicted_price) # y value
# Out:
# [628715.75342466]
# /home/lenovo/.local/lib/python3.10/site-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
reg.coef_ # m value
# Out:
# array([135.78767123])

# %%
reg.intercept_ # c value
# Out:
# 180616.43835616432

# %%
#y=m*x+c
135.78767123*3300+180616.43835616432
# Out:
# 628715.7534151643

# %%
df=pd.read_csv('areas.csv')
print(df)
# Out:
#     area
# 0   1000
# 1   1500
# 2   2300
# 3   3540
# 4   4120
# 5   4560
# 6   5490
# 7   3460
# 8   4750
# 9   2300
# 10  9000
# 11  8600
# 12  7100

# %%
p=reg.predict(df)
print(p)
# Out:
# [ 316404.10958904  384297.94520548  492928.08219178  661304.79452055
#   740061.64383562  799808.21917808  926090.75342466  650441.78082192
#   825607.87671233  492928.08219178 1402705.47945205 1348390.4109589
#  1144708.90410959]

# %%
df['prices'] =p

# %%
d.to_csv("prediction.csv", index=False)

# %%
# %matplotlib inline 
plt.xlabel('area(sqr ft)')
plt.ylabel('price ($)')
plt.scatter(d.area, d.price, color='red')
plt.plot(d.area,reg.predict(d[['area']]), color='blue')
