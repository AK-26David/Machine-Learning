# %% [markdown]
# # Scratch Implementation #

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('prediction.csv')
print(data)
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.scatter(data.area, data.price)
plt.show()

# %%
def loss_function(m,n,points):
    total_error=0
    for i in range(len(points)):
        x= points.iloc[i].area  
        y=points.iloc[i].price
        total_error+= (y-(m*x+b)) **2
        total_error/float(len(points))

# %%
# Gradient Descent Function
def gradient_descent(m_now, b_now, points, L):
    m_gradient = 0
    b_gradient = 0
    n = len(points)
    
    for i in range(n):
        x = points.iloc[i].area 
        y = points.iloc[i].price
        
        m_gradient += -(2/n) * x * (y - (m_now * x + b_now))
        b_gradient += -(2/n) * (y - (m_now * x + b_now))
    
    m = m_now - m_gradient * L
    b = b_now - b_gradient * L
    
    return m, b

# %%
m = 0
b = 0
L = 0.00000001  # Significantly increased learning rate
no_of_iter = 10000  # Increased number of iterations
# Gradient Descent
for i in range(no_of_iter):
    m, b = gradient_descent(m, b, data, L)
    print(f"Iteration {i+1}: m = {m}, b = {b}")

# Plotting
plt.scatter(data.area, data.price, color='blue', label='Data Points')
plt.plot(list(range(2000, 5000)), [m*x + b for x in range(2000, 5000)], color='red', label='Regression Line')
plt.xlabel('Area')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# Iteration 1: m = 41.7, b = 0.01252
# Iteration 2: m = 74.23267117868801, b = 0.022304479749600002
# Iteration 3: m = 99.61335928359136, b = 0.029954816074188477
# Iteration 4: m = 119.4143564136507, b = 0.035940179106088564
# Iteration 5: m = 134.86230194199797, b = 0.0406265966065495
# Iteration 6: m = 146.9141708179644, b = 0.0442996287866225
# Iteration 7: m = 156.31655659928745, b = 0.047182058294971456
# Iteration 8: m = 163.65192170135708, b = 0.04944769123841703
# Iteration 9: m = 169.3746799907622, b = 0.05123212418585418
# Iteration 10: m = 173.83934698076567, b = 0.0526411441538177
# Iteration 11: m = 177.3225014872551, b = 0.05375728193905659
# Iteration 12: m = 180.03991923381923, b = 0.05464492476634702
# Iteration 13: m = 182.15993980474934, b = 0.05535430497170998
# Iteration 14: m = 183.81389500683085, b = 0.05592461181343233
# Iteration 15: m = 185.1042446598746, b = 0.05638641918249199
# Iteration 16: m = 186.11092381489868, b = 0.05676357960507583
# ...
